# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
data = pd.read_excel("Workbook4.xlsx")
data
# Out:
#     PICKED  FREQ
# 0        1   430
# 1        2   430
# 2        3   502
# 3        4   495
# 4        5   472
# 5        6   458
# 6        7   481
# 7        8   484
# 8        9   490
# 9       10   474
# 10      11   454
# 11      12   483
# 12      13   500
# 13      14   454
# 14      15   452
# 15      16   478
# 16      17   473
# 17      18   480
# 18      19   482
# 19      20   484
# 20      21   495
# 21      22   455
# 22      23   481
# 23      24   445
# 24      25   508
# 25      26   473
# 26      27   426
# 27      28   456
# 28      29   470
# 29      30   446
# 30      31   460
# 31      32   439
# 32      33   462
# 33      34   464
# 34      35   457
# 35      36   484
# 36      37   446
# 37      38   460
# 38      39   458
# 39      40   482
# 40      41   448
# 41      42   456
# 42      43   478
# 43      44   460
# 44      45   484
# 45      46   487
# 46      47   436
# 47      48   484
# 48      49   475

# %%
data.plot.bar(x= 'PICKED', fontsize =12, y= 'FREQ', color='magenta')
plt.title("Frequency of 6/49 nums", fontsize=20)
plt.rcParams['figure.figsize'] = [30, 20]
